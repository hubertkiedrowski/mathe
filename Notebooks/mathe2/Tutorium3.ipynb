# %%
from sympy import *

# %% [markdown]
# # Rechneraufgaben

# %% [markdown]
# ## Aufgabe 1
# #### Geben Sie die dreißigste Nachkommastelle von $\sqrt{3}$ an.

# %%
N(pi,32)
# Out:
# 3.1415926535897932384626433832795

# %% [markdown]
# #### Geben Sie die 6. Nachkommastelle von $e^{\pi e^{2}}$ an.

# %%
N(E**pi*E**2,30)
# Out:
# 170.987876031717223191730407943

# %% [markdown]
# #### Geben Sie die achtzehnte Nachkommastelle von $\sqrt{^2/_3}$ an.

# %%
N(sqrt(2/3),18)
# Out:
# 0.816496580927726034

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 2
# #### Welchen Wert muss $n \ge 0$ haben, damit $\sum \limits _{k=1} ^{n} \dfrac{2(nk+k)}{n} = 676 $ gilt?

# %%
for x in range(1000):

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 3
# ##### Geben Sie den folgenden Ausdruck in möglichst einfacher Form an: <br><br> <center>$ (n^2 + 2)^2 - \sum \limits _{k=1} ^{n} 4k^3 $</center>

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 4
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# # Manuelle Aufgaben

# %% [markdown]
# ## Aufgabe 5
# #### Welche der folgenden Aussagen sind wahr?
# #### A. $3n ∈ O(2n)$
# #### B. $2n ∈ O(3n)$
# #### C. $ 2^{n+42} ∈ O(3^n)$
# #### D. $ (n^4 + n^3 + n^2 + n)^4 ∈ O(n^{10})$
# #### E. $ \prod_{k=0}^{3} (n + k) ∈ O(n^3) $
# #### F. $ \prod_{k=1}^{3} (n^k + k) ∈ O(n^3) $

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 6
# #### Geben Sie die dritte Nachkommastelle von $10^{100} /7$ an.

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 7
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Aufgabe 8
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# # Zusatz:

# %% [markdown]
# ## Aufgabe 5 mit Rechner
# #### Welche der folgenden Aussagen sind wahr?
# #### A. $3n ∈ O(2n)$
# #### B. $2n ∈ O(3n)$
# #### C. $ 2^{n+42} ∈ O(3^n)$
# #### D. $ (n^4 + n^3 + n^2 + n)^4 ∈ O(n^{10})$
# #### E. $ \prod_{k=0}^{3} (n + k) ∈ O(n^3) $
# #### F. $ \prod_{k=1}^{3} (n^k + k) ∈ O(n^3) $

# %% [markdown]
# ## Teilaufgabe 1 mit Rechner
# #### Geben Sie die dritte Nachkommastelle von $10^{100} /7$ an.
